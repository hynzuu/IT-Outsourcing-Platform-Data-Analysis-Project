# %%
data.head()
# Out:
#   판매자ID         판매자  판매 서비스 수    총 판매 금액 프리미엄 서비스 가입여부 신속 알람 서비스 사용여부  R_x  \
# 0  V2_0         김러그       326  147927420            가입            미사용  142
# 1  V2_1        디프라이        43  146832200            가입            미사용   59
# 2  V2_2    Sailorkr        14  140029000            가입            미사용   86
# 3  V2_3  신뢰할만한지식인65        16  130713200            가입            미사용  103
# 4  V2_4         에픽핫        18  126229400            가입            미사용  132
#
#    평균평점  총프로그램수정횟수  총거래취소여부        평균수수료율  총추가결제금액      최근거래일자   총이용자수
# 0   5.0       45.0      0.0  4.484100e+05  1745760  2021-06-24  1304.0
# 1   0.0       21.0      0.0  3.410840e+06   166100  2021-06-04     0.0
# 2   0.0        0.0      0.0  1.000104e+07    14500  2021-05-22     0.0
# 3   0.0        1.0      0.0  8.166038e+06    56600  2021-03-20     0.0
# 4   5.0       18.0      0.0  7.006372e+06   114700  2021-05-25    36.0

# %%
import pandas as pd
import numpy as np

# 데이터 불러오기
#file_path = '/mnt/data/expert_df_2.csv'
data = pd.read_csv('./expert_df_2.csv')

# 필요한 열만 선택
df = data[['판매자ID','판매 서비스 수', '총 판매 금액', '최근거래일자', '평균수수료율']]

# Check the data type of '총 판매 금액' column
print(df['총 판매 금액'].dtype)

# If it's not a string, convert it to string first
if df['총 판매 금액'].dtype != object:
    df['총 판매 금액'] = df['총 판매 금액'].astype(str)

# Now you can apply the string methods
df['총 판매 금액'] = df['총 판매 금액'].str.replace(',', '').astype(float)

# 최근거래일자 처리
df['최근거래일자'] = pd.to_datetime(df['최근거래일자'])
current_date = pd.to_datetime('2021-07-01')  # 기준일 설정 (예: 2021-07-01)
df['Recency'] = (current_date - df['최근거래일자']).dt.days

# ... rest of your code ...
# Out:
# int64
# <ipython-input-10-8ab172fded66>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['총 판매 금액'] = df['총 판매 금액'].astype(str)
# <ipython-input-10-8ab172fded66>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['총 판매 금액'] = df['총 판매 금액'].str.replace(',', '').astype(float)
# <ipython-input-10-8ab172fded66>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.head()
# Out:
#   판매자ID  판매 서비스 수      총 판매 금액     최근거래일자        평균수수료율  Recency
# 0  V2_0       326  147927420.0 2021-06-24  4.484100e+05        7
# 1  V2_1        43  146832200.0 2021-06-04  3.410840e+06       27
# 2  V2_2        14  140029000.0 2021-05-22  1.000104e+07       40
# 3  V2_3        16  130713200.0 2021-03-20  8.166038e+06      103
# 4  V2_4        18  126229400.0 2021-05-25  7.006372e+06       37

# %%
df.columns
# Out:
# Index(['판매 서비스 수', '총 판매 금액', '최근거래일자', '평균수수료율', 'Recency', 'R_Score',
#        'F_Score', 'M_Score', 'RFM_Score'],
#       dtype='object')

# %%
df[['Recency','판매 서비스 수','총 판매 금액']].hist(bins=50)
# Out:
# array([[<Axes: title={'center': 'Recency'}>,
#         <Axes: title={'center': '판매 서비스 수'}>],
#        [<Axes: title={'center': '총 판매 금액'}>, <Axes: >]], dtype=object)

# %%
# prompt: df[['Recency','판매 서비스 수','총 판매 금액']].hist(bins=50) 한줄에 이쁜 그래프로

import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(15, 5))

# Create subplots
plt.subplot(1, 3, 1)
df['Recency'].hist(bins=50)
plt.title('Recency')

plt.subplot(1, 3, 2)
df['판매 서비스 수'].hist(bins=50)
plt.title('판매 서비스 수')

plt.subplot(1, 3, 3)
df['총 판매 금액'].hist(bins=50)
plt.title('총 판매 금액')

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
ID=df['판매자ID']

# %%
df['R_Score'] = pd.qcut(df['Recency'], 4, labels=[4, 3, 2, 1])
df['F_Score'] = pd.qcut(df['판매 서비스 수'].rank(method='first'), 4, labels=[1, 2, 3, 4])
df['M_Score'] = pd.qcut(df['총 판매 금액'], 4, labels=[1, 2, 3, 4])

# RFM 점수 합산
df['RFM_Score'] = df['R_Score'].astype(int) + df['F_Score'].astype(int) + df['M_Score'].astype(int)

# 클러스터링을 위해 필요 없는 열 제거
rfm_df = df[['R_Score', 'F_Score', 'M_Score', 'RFM_Score']]
# Out:
# <ipython-input-15-985b73a7df1d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['R_Score'] = pd.qcut(df['Recency'], 4, labels=[4, 3, 2, 1])
# <ipython-input-15-985b73a7df1d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['F_Score'] = pd.qcut(df['판매 서비스 수'].rank(method='first'), 4, labels=[1, 2, 3, 4])
# <ipython-input-15-985b73a7df1d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
rfm_df[[['R_Score', 'F_Score', 'M_Score']]]

# %%
# prompt: rfm_df[[['R_Score', 'F_Score', 'M_Score']]] score어 높을 수록 진한 색깔 표현

import matplotlib.pyplot as plt
import seaborn as sns

# 'RFM_Score'를 기준으로 정렬
rfm_df_sorted = rfm_df.sort_values('RFM_Score')

# 히트맵 그리기
plt.figure(figsize=(8, 6))
sns.heatmap(rfm_df_sorted[['R_Score', 'F_Score', 'M_Score']], cmap='YlGnBu', annot=True, fmt='d', linewidths=.5)
plt.title('RFM Scores Heatmap')
plt.show()

# %%
rfm_df.
# Out:
#   R_Score F_Score M_Score  RFM_Score
# 0       3       4       4         11
# 1       2       3       4          9
# 2       2       2       4          8
# 3       1       2       4          7
# 4       2       2       4          8

# %%
X=rfm_df[['R_Score', 'F_Score', 'M_Score']]
X['Weighted_RFM_Score'] = X['R_Score'].astype(int) * 0.2 + X['F_Score'].astype(int) * 0.5 + X['M_Score'].astype(int) * 0.3

# %%
X=X.astype(int)

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

kmean=KMeans(n_clusters=8,n_init='auto',random_state=111)
kmean.fit(X)
kmean.cluster_centers_, kmean.inertia_
# Out:
# (array([[1.2155477 , 1.41342756, 2.53710247, 1.22614841],
#         [2.96415771, 3.14336918, 3.74551971, 2.94982079],
#         [4.        , 4.        , 4.        , 4.        ],
#         [1.        , 1.20437956, 1.        , 1.        ],
#         [3.4479638 , 2.71493213, 1.88687783, 2.        ],
#         [2.41545894, 1.38164251, 1.06763285, 1.        ],
#         [2.02605863, 2.37459283, 2.59283388, 2.        ],
#         [3.73913043, 3.85375494, 2.86561265, 3.        ]]),
#  1282.7165639636794)

# %%
! pip install yellowbrick

# %%
from yellowbrick.cluster import KElbowVisualizer

KEV=KElbowVisualizer(kmean,k=10,n_init='auto')
KEV.fit(X)
KEV.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
n_cluster=4
k_means=KMeans(n_clusters=n_cluster,n_init='auto',random_state=111)
k_means.fit(X)
# Out:
# KMeans(n_clusters=4, n_init='auto', random_state=111)

# %%
pd.Series(k_means.labels_).value_counts()
# Out:
# 0    671
# 2    625
# 3    435
# 1    335
# Name: count, dtype: int64

# %%
silhouettes_avg=silhouette_score(X,k_means.labels_)

# %%
silhouettes_avg
# Out:
# 0.42177822866321696

# %%
# https://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html
from sklearn.metrics import silhouette_samples
import matplotlib.cm as cm

# Create a subplot with 1 row and 2 columns
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_size_inches(18, 7)

# The 1st subplot is the silhouette plot
# The silhouette coefficient can range from -1, 1 but in this example all
# lie within [-0.1, 1]
ax1.set_xlim([-0.1, 1])
# The (n_clusters+1)*10 is for inserting blank space between silhouette
# plots of individual clusters, to demarcate them clearly.
ax1.set_ylim([0, len(X) + (n_cluster + 1) * 10])

cluster_labels = k_means.labels_
sample_silhouette_values = silhouette_samples(X, cluster_labels)

y_lower = 10
for i in range(n_cluster):
    # Aggregate the silhouette scores for samples belonging to
    # cluster i, and sort them
    ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

    ith_cluster_silhouette_values.sort()

    size_cluster_i = ith_cluster_silhouette_values.shape[0]
    y_upper = y_lower + size_cluster_i

    color = cm.nipy_spectral(float(i) / n_cluster)
    ax1.fill_betweenx(
        np.arange(y_lower, y_upper),
        0,
        ith_cluster_silhouette_values,
        facecolor=color,
        edgecolor=color,
        alpha=0.7,
    )

    # Label the silhouette plots with their cluster numbers at the middle
    ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

    # Compute the new y_lower for next plot
    y_lower = y_upper + 10  # 10 for the 0 samples

ax1.set_title("The silhouette plot for the various clusters.")
ax1.set_xlabel("The silhouette coefficient values")
ax1.set_ylabel("Cluster label")

# The vertical line for average silhouette score of all the values
ax1.axvline(x=silhouettes_avg, color="red", linestyle="--")

ax1.set_yticks([])  # Clear the yaxis labels / ticks
ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

# 2nd Plot showing the actual clusters formed
colors = cm.nipy_spectral(cluster_labels.astype(float) / n_cluster)
ax2.scatter(
    X.iloc[:, 0], X.iloc[:, 1], marker=".", s=30, lw=0, alpha=0.7, c=colors, edgecolor="k"
)

# Labeling the clusters
centers = k_means.cluster_centers_
# Draw white circles at cluster centers
ax2.scatter(
    centers[:, 0],
    centers[:, 1],
    marker="o",
    c="white",
    alpha=1,
    s=200,
    edgecolor="k",
)

for i, c in enumerate(centers):
    ax2.scatter(c[0], c[1], marker="$%d$" % i, alpha=1, s=50, edgecolor="k")

ax2.set_title("The visualization of the clustered data.")
ax2.set_xlabel("Feature space for the 1st feature")
ax2.set_ylabel("Feature space for the 2nd feature")

plt.suptitle(
    "Silhouette analysis for KMeans clustering on sample data with n_clusters = %d"
    % n_cluster,
    fontsize=14,
    fontweight="bold",
)

plt.show()

# %%
data['Cluster']=k_means.labels_
data.head()
# Out:
#   판매자ID         판매자  판매 서비스 수    총 판매 금액 프리미엄 서비스 가입여부 신속 알람 서비스 사용여부  R_x  \
# 0  V2_0         김러그       326  147927420            가입            미사용  142
# 1  V2_1        디프라이        43  146832200            가입            미사용   59
# 2  V2_2    Sailorkr        14  140029000            가입            미사용   86
# 3  V2_3  신뢰할만한지식인65        16  130713200            가입            미사용  103
# 4  V2_4         에픽핫        18  126229400            가입            미사용  132
#
#    평균평점  총프로그램수정횟수  총거래취소여부        평균수수료율  총추가결제금액      최근거래일자   총이용자수  \
# 0   5.0       45.0      0.0  4.484100e+05  1745760  2021-06-24  1304.0
# 1   0.0       21.0      0.0  3.410840e+06   166100  2021-06-04     0.0
# 2   0.0        0.0      0.0  1.000104e+07    14500  2021-05-22     0.0
# 3   0.0        1.0      0.0  8.166038e+06    56600  2021-03-20     0.0
# 4   5.0       18.0      0.0  7.006372e+06   114700  2021-05-25    36.0
#
#    Cluster
# 0        2
# 1        3
# 2        3
# 3        3
# 4        3

# %%
rank_cluster=data.pivot_table(index='Cluster',values=['판매 서비스 수', '총 판매 금액'],aggfunc='median').reset_index()
rank_cluster
# Out:
#    Cluster     총 판매 금액  판매 서비스 수
# 0        0    466500.0       5.0
# 1        1   2384760.0      69.0
# 2        2  19623800.0     303.0
# 3        3   7903200.0      26.0

# %% [markdown]
# 판매자를 기준으로 군집을 했을 때, 총 판매 금액이 많고 판매 서비스 수가 많은 판매자 집단에게는 일반적으로 낮은 수수료율을 적용하는 것이 일반적인 전략입니다. 그 이유는 다음과 같습니다:
#
# 1. **규모의 경제**:
#    - 대형 판매자들은 대량의 거래를 처리하므로, 낮은 수수료율을 적용하더라도 플랫폼이 얻는 총 수익은 상당히 큽니다.
#
# 2. **유인 효과**:
#    - 대형 판매자들에게 낮은 수수료율을 제공하면, 이들이 플랫폼에 계속 머물며 더 많은 거래를 유도할 수 있습니다. 이는 플랫폼의 전체 거래량과 수익을 증가시킵니다.
#
# 3. **경쟁력 강화**:
#    - 낮은 수수료율을 통해 대형 판매자들에게 경쟁력을 제공하면, 다른 플랫폼으로의 이탈을 방지할 수 있습니다. 이는 특히 대형 판매자들이 다른 플랫폼으로 이전할 가능성이 높기 때문에 중요합니다.
#
# 4. **파트너십 강화**:
#    - 대형 판매자들과의 강한 파트너십을 통해 상호 이익을 극대화할 수 있습니다. 이들은 종종 플랫폼에 중요한 피드백을 제공하고, 공동 마케팅 캠페인 등을 통해 플랫폼의 성장을 도울 수 있습니다.
#
# 따라서, 총 판매 금액이 많고 판매 서비스 수가 많은 판매자 집단에게는 **낮은 수수료율**을 적용하는 것이 전략적으로 더 유리합니다. 이는 플랫폼의 성장과 수익성에 긍정적인 영향을 미칠 수 있습니다.

# %%
판매 금액이 작고 판매 서비스 수가 적은 군집에는 높은 수수료율을 적용하는 대신, 판매자에게는 매칭의 우선순위 제공
판매 금액이 크고 판매 서비스 수가 많은 군집에는 낮은 수수료율을 적용하여, 전문인력의 이탈 방지
# Out:
#   File "<ipython-input-1-1a3a82602fab>", line 1
#     판매 금액이 작고 판매 서비스 수가 적은 군집에는 높은 수수료율을 적용하는 대신, 판매자에게는 매칭의 우선순위 제공
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 유입경로 확인

# %%
! pip install koreanize-matplotlib
import koreanize_matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 59.9 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customer_df=pd.read_csv('./Customer_data.csv')

# %%
customer_df.head()
# Out:
#            고객ID      사용기기        사용OS    유입경로  회원상태  거주지    연령   성별  서비스총구매수  \
# 0    1001010041    iPhone   iOS11.4.1     유튜브  정상회원  경기도  25.0   남성        1
# 1   10010100410  SM-N935S  Android7.0    검색광고  정상회원  경기도  26.0  NaN        1
# 2  100101004108    iPhone     iOS12.0  네이버블로그  정상회원  경기도  23.0   남성        1
# 3  100101004109    iPhone   iOS11.4.1   인스타그램  정상회원  경기도  20.0   남성        1
# 4  100101004112    iPhone   iOS11.4.1    직접검색  정상회원  경기도  28.0   남성        1
#
#       총구매금액  총수정요청수  총추가결제금액
# 0   44500.0     0.0    14500
# 1   44500.0     0.0    14500
# 2   34500.0     0.0    14500
# 3  364500.0     0.0    14500
# 4   34500.0     0.0    14500

# %%
customer_df.isna().sum()
# Out:
# 고객ID           0
# 사용기기           0
# 사용OS           0
# 유입경로        1606
# 회원상태           0
# 거주지            0
# 연령          1804
# 성별         10259
# 서비스총구매수        0
# 총구매금액          5
# 총수정요청수         0
# 총추가결제금액        0
# dtype: int64

# %%
customer_df['유입경로'].value_counts()
# Out:
# 유입경로
# 유튜브       52111
# 네이버블로그    38251
# 검색광고      13765
# 인스타그램     13360
# 네이버카페      9623
# 구글광고       3377
# 페이스북       2395
# 직접검색       1901
# 다음카페        773
# 뉴스광고        364
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=customer_df,x='유입경로',order=customer_df['유입경로'].value_counts().index ,palette='Set2')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-8-90b07dd7b4ad>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=customer_df,x='유입경로',order=customer_df['유입경로'].value_counts().index ,palette='Set2')
