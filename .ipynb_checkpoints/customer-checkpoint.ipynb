# %%
! pip install koreanize-matplotlib
import koreanize_matplotlib
# Out:
# Failed to start the Kernel 'Python 3.11.9'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. listen EFAULT: bad address in system call argument 127.0.0.1:9003

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
customer= pd.read_csv('./Customer_data.csv')
expert_Data= pd.read_csv('./Expert_Data.csv')
Log_Data02= pd.read_csv('./Log_Data02.csv')
Service_Data= pd.read_csv('./Service_Data.csv')

# %%
customer.head()
# Out:
#            고객ID      사용기기        사용OS    유입경로  회원상태  거주지    연령   성별  서비스총구매수
# 0    1001010041    iPhone   iOS11.4.1     유튜브  정상회원  경기도  25.0   남성        1  \
# 1   10010100410  SM-N935S  Android7.0    검색광고  정상회원  경기도  26.0  NaN        1
# 2  100101004108    iPhone     iOS12.0  네이버블로그  정상회원  경기도  23.0   남성        1
# 3  100101004109    iPhone   iOS11.4.1   인스타그램  정상회원  경기도  20.0   남성        1
# 4  100101004112    iPhone   iOS11.4.1    직접검색  정상회원  경기도  28.0   남성        1
#
#       총구매금액  총수정요청수  총추가결제금액
# 0   44500.0     0.0    14500
# 1   44500.0     0.0    14500
# 2   34500.0     0.0    14500
# 3  364500.0     0.0    14500
# 4   34500.0     0.0    14500

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137526 entries, 0 to 137525
# Data columns (total 12 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   고객ID     137526 non-null  int64
#  1   사용기기     137526 non-null  object
#  2   사용OS     137526 non-null  object
#  3   유입경로     135920 non-null  object
#  4   회원상태     137526 non-null  object
#  5   거주지      137526 non-null  object
#  6   연령       135722 non-null  float64
#  7   성별       127267 non-null  object
#  8   서비스총구매수  137526 non-null  int64
#  9   총구매금액    137521 non-null  float64
#  10  총수정요청수   137526 non-null  float64
#  11  총추가결제금액  137526 non-null  int64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 12.6+ MB

# %%
customer.isna().sum()
# Out:
# 고객ID           0
# 사용기기           0
# 사용OS           0
# 유입경로        1606
# 회원상태           0
# 거주지            0
# 연령          1804
# 성별         10259
# 서비스총구매수        0
# 총구매금액          5
# 총수정요청수         0
# 총추가결제금액        0
# dtype: int64

# %%
customer.shape
# Out:
# (137526, 12)

# %% [markdown]
# ### 결측치 삭제

# %%
drop_df=customer.dropna()

# %%
drop_df.shape
# Out:
# (124107, 12)

# %%
drop_df.isna().sum()
# Out:
# 고객ID       0
# 사용기기       0
# 사용OS       0
# 유입경로       0
# 회원상태       0
# 거주지        0
# 연령         0
# 성별         0
# 서비스총구매수    0
# 총구매금액      0
# 총수정요청수     0
# 총추가결제금액    0
# dtype: int64

# %%
drop_df.drop('고객ID',axis=1,inplace=True)

# %%
drop_df.head()
# Out:
#        사용기기          사용OS    유입경로  회원상태  거주지    연령  성별  서비스총구매수     총구매금액
# 0    iPhone     iOS11.4.1     유튜브  정상회원  경기도  25.0  남성        1   44500.0  \
# 2    iPhone       iOS12.0  네이버블로그  정상회원  경기도  23.0  남성        1   34500.0
# 3    iPhone     iOS11.4.1   인스타그램  정상회원  경기도  20.0  남성        1  364500.0
# 4    iPhone     iOS11.4.1    직접검색  정상회원  경기도  28.0  남성        1   34500.0
# 5  SM-G955N  Android8.0.0    검색광고  정상회원  경상도  26.0  남성        1   24500.0
#
#    총수정요청수  총추가결제금액
# 0     0.0    14500
# 2     0.0    14500
# 3     0.0    14500
# 4     0.0    14500
# 5     0.0    14500

# %% [markdown]
# ## 통계량

# %%
drop_df.describe().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_ba61c_row0_col0, #T_ba61c_row0_col1, #T_ba61c_row0_col3, #T_ba61c_row7_col2, #T_ba61c_row7_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ba61c_row0_col2, #T_ba61c_row1_col0, #T_ba61c_row1_col1, #T_ba61c_row1_col2, #T_ba61c_row1_col3, #T_ba61c_row2_col0, #T_ba61c_row2_col1, #T_ba61c_row2_col3, #T_ba61c_row3_col0, #T_ba61c_row3_col1, #T_ba61c_row3_col2, #T_ba61c_row3_col3, #T_ba61c_row3_col4, #T_ba61c_row4_col0, #T_ba61c_row4_col1, #T_ba61c_row4_col2, #T_ba61c_row4_col3, #T_ba61c_row4_col4, #T_ba61c_row5_col0, #T_ba61c_row5_col1, #T_ba61c_row5_col2, #T_ba61c_row5_col3, #T_ba61c_row5_col4, #T_ba61c_row6_col0, #T_ba61c_row6_col1, #T_ba61c_row6_col2, #T_ba61c_row6_col3, #T_ba61c_row7_col0, #T_ba61c_row7_col1, #T_ba61c_row7_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ba61c_row0_col4 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_ba61c_row1_col4 {
#   background-color: #f6faff;
#   color: #000000;
# }
# ...

# %%
# 연령대는 0~85세

# %%
drop_df.describe(include='O')
# Out:
#           사용기기          사용OS    유입경로    회원상태     거주지      성별
# count   124107        124107  124107  124107  124107  124107
# unique     243            45      10       3       7       2
# top     iPhone  Android8.0.0     유튜브    정상회원     경기도      남성
# freq     49643         44149   47537  119619   44098   91513

# %%
# 성별별로 가설 검정
# 회원 상태별 ..

# %% [markdown]
# ### 이상치 제거 ( 연령 =0 세)

# %%
drop_df[drop_df['연령']==0]
# Out:
#             사용기기          사용OS    유입경로  회원상태  거주지   연령  성별  서비스총구매수     총구매금액
# 839     SM-G930K    Android7.0  네이버블로그  정상회원  서울시  0.0  남성        8   90000.0  \
# 1658    SM-A520S  Android8.0.0   인스타그램  정상회원  경기도  0.0  여성        5  370000.0
# 3610    SM-G610S    Android7.0     유튜브  정상회원  전라도  0.0  남성        4  145000.0
# 5116    SM-N960N  Android8.1.0   네이버카페  정상회원  서울시  0.0  남성        2   47000.0
# 5944    LG-F700S  Android6.0.1   인스타그램  정상회원  경상도  0.0  남성        2   28000.0
# ...          ...           ...     ...   ...  ...  ...  ..      ...       ...
# 131593  SM-G928K    Android7.0     유튜브  정상회원  경기도  0.0  여성        2  218200.0
# 131842    iPhone     iOS10.3.3    다음카페  정상회원  경기도  0.0  여성        2  133200.0
# 135051  SM-G950N  Android8.0.0   인스타그램  정상회원  서울시  0.0  여성        1   10000.0
# 135879    iPhone     iOS10.1.1    검색광고  정상회원  경기도  0.0  여성        2   19400.0
# 137084    iPhone     iOS11.4.1     유튜브  정상회원  전라도  0.0  여성        1   15000.0
#
#         총수정요청수  총추가결제금액
# ...

# %%
drop_df=drop_df[drop_df['연령']!=0]

# %%
drop_df.shape
# Out:
# (123990, 11)

# %%
drop_df['연령'].describe()
# Out:
# count    123990.000000
# mean         27.719042
# std           6.587466
# min          19.000000
# 25%          23.000000
# 50%          26.000000
# 75%          31.000000
# max          85.000000
# Name: 연령, dtype: float64

# %%
# 고객 특징

# %% [markdown]
# ## 수치형/ 범주형 그래프

# %%
cat_col=drop_df.select_dtypes('object').columns

# %%
cat_col
# Out:
# Index(['사용기기', '사용OS', '유입경로', '회원상태', '거주지', '성별'], dtype='object')

# %%
num_col=drop_df.select_dtypes(['int64','float64']).columns

# %%
num_col
# Out:
# Index(['연령', '서비스총구매수', '총구매금액', '총수정요청수', '총추가결제금액'], dtype='object')

# %% [markdown]
# ### 수치형 그래프

# %%
# 수치형
plt.figure(figsize=(20, 25))


for i, feature in enumerate(num_col, 1):
    plt.subplot(5, 3, i)
    sns.histplot(drop_df[feature], bins=30, kde=True, color='skyblue', edgecolor='black')
    plt.title("Histogram: " + feature)
    plt.xlabel(feature)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 범주형 그래프

# %%
# 범주형

plt.figure(figsize=(20, 25))


for i, feature in enumerate(cat_col, 1):
    plt.subplot(5,3, i)
    sns.histplot(drop_df[feature], bins=30, color='skyblue', edgecolor='black')
    plt.title("Histogram: " + feature)
    plt.xlabel(feature)

plt.tight_layout()
plt.show()

# %%
# 상위 10개 사용 기기

drop_df['사용기기'].value_counts().sort_values(ascending=False)[:10].plot.bar()
# Out:
# <Axes: xlabel='사용기기'>

# %%
# 상위 10개의 사용OS

drop_df['사용OS'].value_counts().sort_values(ascending=False)[:10].plot.bar()
# Out:
# <Axes: xlabel='사용OS'>

# %%
# 상위 5개의 유입경로

drop_df['유입경로'].value_counts().sort_values(ascending=False)[:6].plot.bar()
# Out:
# <Axes: xlabel='유입경로'>

# %%
# box plot

plt.figure(figsize=(20, 25))


for i, feature in enumerate(num_col, 1):
    plt.subplot(5, 3, i)
    sns.boxplot(data=drop_df, x=feature,hue='성별')
    plt.title("Boxplot: " + feature)
    plt.xlabel(feature)

plt.tight_layout()
plt.show()

# %%
# heatmap
# 범주형 :유입경로,	회원상태,	거주지,	성별 별로 변수들 간의 cross table

cross_tab=pd.crosstab(drop_df['유입경로'],drop_df['회원상태'])
sns.heatmap(cross_tab,annot=True,cmap='YlGnBu')
plt.title('유입경로별 회원상태')
plt.show( )

# %%
cross_tab2=pd.crosstab(drop_df['회원상태'],drop_df['성별'])
sns.heatmap(cross_tab2,annot=True,cmap='YlGnBu')
plt.title('회원상태별 성별')
plt.show( )

# %%
cross_tab3=pd.crosstab(drop_df['회원상태'],drop_df['거주지'])
sns.heatmap(cross_tab3,annot=True,cmap='YlGnBu')
plt.title('회원상태별 거주지')
plt.show( )

# %% [markdown]
# ## 상관관계

# %%
corr=drop_df[num_col].corr()

mask=np.zeros_like(corr)
mask[np.triu_indices_from(mask)]=True

plt.figure(figsize=(7,7))
sns.heatmap(corr,annot=True,cmap='YlGnBu',linewidths=0.5,mask=mask)
plt.title('상관관계')
plt.show()

# %%
# 서비스 총 구매수와 총수정요청수는 양의 상관관계
# 서비스 총 구매수와 총구매금액은 양의 상관관계

# %% [markdown]
# ### 연령대 변수 생성

# %%
drop_df['연령대']=drop_df['연령'].apply(lambda x:x//10*10)

# %%
drop_df['연령대'].value_counts()
# Out:
# 연령대
# 20.0    82791
# 30.0    30995
# 40.0     7268
# 10.0     2452
# 50.0      446
# 60.0       24
# 80.0       14
# Name: count, dtype: int64

# %%
# 연령대

drop_df['연령대'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='연령대'>

# %%
# 20대가 주요 고객

# %% [markdown]
# ## 가설 검정

# %% [markdown]
# ▶ 성별별로 서비스총구매수에 유의미한 차이가 있다.

# %%
# 성별별로 서비스총구매수에 유의미한 차이가 있다.

# %%
female=drop_df[drop_df['성별']=='여성']
male=drop_df[drop_df['성별']=='남성']

# %%
# 정규성 검정

import scipy.stats as stats

# %%
stats.normaltest(female['서비스총구매수'])
# Out:
# NormaltestResult(statistic=48980.81457861929, pvalue=0.0)

# %%
# pvalue<0.05 / 대립가설 채택 / 정규성 x

# %%
stats.normaltest(male['서비스총구매수'])
# Out:
# NormaltestResult(statistic=134312.09784042375, pvalue=0.0)

# %%
# pvalue<0.05 / 대립가설 채택 / 정규성 x

# %%
# 평균에 차이 있는지

stats.ranksums(female['서비스총구매수'],male['서비스총구매수'])
# Out:
# RanksumsResult(statistic=-0.14965944371010395, pvalue=0.8810333069518607)

# %%
# pvalue>0.0.5 / 귀무가설 채택 / 차이 없다.

# %%
female['서비스총구매수'].mean()
# Out:
# 2.4746022971561943

# %%
male['서비스총구매수'].mean()
# Out:
# 2.514711029443934

# %% [markdown]
# ▶ 성별별로 추가 결제 금액에 유의미한 차이가 있다.

# %%
# 정규성 확인

print(male['총추가결제금액'].mean(),female['총추가결제금액'].mean())
# Out:
# 9899.922671391696 9870.594005282232

# %% [markdown]
# #### > 카이제곱 검정

# %%
# 성별과 회원 상태와의 관계
# 유입경로와 회원 상태와의 관계

# %%
# 성별과 회원 상태 간의 카이제곱 검정
gender_membership_crosstab = pd.crosstab(drop_df['성별'], drop_df['회원상태'])
gender_membership_chi2, gender_membership_p, _, _ = stats.chi2_contingency(gender_membership_crosstab)

# %%
# 유입경로와 회원 상태 간의 카이제곱 검정
source_membership_crosstab = pd.crosstab(drop_df['유입경로'], drop_df['회원상태'])
source_membership_chi2, source_membership_p, _, _ = stats.chi2_contingency(source_membership_crosstab)

# %%
print("성별과 회원 상태 간의 관계")
print("카이제곱 통계량:", gender_membership_chi2)
print("p-값:", gender_membership_p)
# Out:
# 성별과 회원 상태 간의 관계
# 카이제곱 통계량: 0.6712481960758963
# p-값: 0.7148917845389269

# %%
print("\n유입경로와 회원 상태 간의 관계")
print("카이제곱 통계량:", source_membership_chi2)
print("p-값:", source_membership_p)
# Out:
# 유입경로와 회원 상태 간의 관계
# 카이제곱 통계량: 14.622057555412932
# p-값: 0.6877334667815695

# %%
# 둘 다 pvalue>0.05 로 두 변수간의 의미있는 영향이 없음

# %% [markdown]
# ### Clustering

# %%
drop_df.head()
# Out:
#        사용기기          사용OS    유입경로  회원상태  거주지    연령  성별  서비스총구매수     총구매금액  \
# 0    iPhone     iOS11.4.1     유튜브  정상회원  경기도  25.0  남성        1   44500.0
# 2    iPhone       iOS12.0  네이버블로그  정상회원  경기도  23.0  남성        1   34500.0
# 3    iPhone     iOS11.4.1   인스타그램  정상회원  경기도  20.0  남성        1  364500.0
# 4    iPhone     iOS11.4.1    직접검색  정상회원  경기도  28.0  남성        1   34500.0
# 5  SM-G955N  Android8.0.0    검색광고  정상회원  경상도  26.0  남성        1   24500.0
#
#    총수정요청수  총추가결제금액   연령대
# 0     0.0    14500  20.0
# 2     0.0    14500  20.0
# 3     0.0    14500  20.0
# 4     0.0    14500  20.0
# 5     0.0    14500  20.0

# %%
cluster=drop_df[['연령','총추가결제금액','서비스총구매수']]

# %%
cluster.hist(bins=50)
# Out:
# array([[<Axes: title={'center': '연령'}>,
#         <Axes: title={'center': '총추가결제금액'}>],
#        [<Axes: title={'center': '서비스총구매수'}>, <Axes: >]], dtype=object)

# %%
#from sklearn.preprocessing import LabelEncoder

#le=LabelEncoder()
#cluster['성별']=le.fit_transform(cluster['성별'])
#cluster['유입경로']=le.fit_transform(cluster['유입경로'])

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %%
kmean=KMeans(n_clusters=8,n_init='auto',random_state=111)
kmean.fit(cluster)
kmean.cluster_centers_, kmean.inertia_
# Out:
# (array([[2.77207152e+01, 1.23533420e+04, 2.23933510e+00],
#         [2.77195889e+01, 1.46425109e+03, 2.18645001e+00],
#         [2.75749326e+01, 5.68236954e+04, 5.27547170e+00],
#         [2.79265770e+01, 1.05774705e+05, 9.92140641e+00],
#         [2.63571429e+01, 5.57957143e+05, 1.21428571e+00],
#         [2.77386150e+01, 2.98436573e+04, 3.57564923e+00],
#         [2.78469388e+01, 1.95883622e+05, 2.16377551e+01],
#         [4.80000000e+01, 1.44520000e+06, 1.00000000e+00]]),
#  2606020854907.1904)

# %%
kmean.cluster_centers_.shape
# Out:
# (8, 3)

# %% [markdown]
# ### Elbow Method

# %%
! pip install yellowbrick

# %%
from yellowbrick.cluster import KElbowVisualizer

KEV=KElbowVisualizer(kmean,k=10,n_init='auto')
KEV.fit(cluster)
KEV.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
n_cluster=5
k_means=KMeans(n_clusters=n_cluster,n_init='auto',random_state=111)
k_means.fit(cluster)
# Out:
# KMeans(n_clusters=5, n_init='auto', random_state=111)

# %%
pd.Series(k_means.labels_).value_counts()
# Out:
# 1    78149
# 0    37765
# 3     7117
# 2      939
# 4       20
# Name: count, dtype: int64

# %%
silhouettes_avg=silhouette_score(cluster,k_means.labels_)
silhouettes_avg
# Out:
# 0.6538396670060077

# %%
from sklearn.metrics import silhouette_samples
import matplotlib.cm as cm
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have already performed clustering and have the necessary variables:
# k_means, n_cluster, silhouettes_avg

# Create a subplot with 1 row and 2 columns
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_size_inches(18, 7)

# The 1st subplot is the silhouette plot
# The silhouette coefficient can range from -1, 1 but in this example all
# lie within [-0.1, 1]
ax1.set_xlim([-0.1, 1])
# The (n_clusters+1)*10 is for inserting blank space between silhouette
# plots of individual clusters, to demarcate them clearly.
ax1.set_ylim([0, len(cluster) + (n_cluster + 1) * 10])

cluster_labels = k_means.labels_
sample_silhouette_values = silhouette_samples(cluster, cluster_labels)

y_lower = 10
for i in range(n_cluster):
    # Aggregate the silhouette scores for samples belonging to
    # cluster i, and sort them
    ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

    ith_cluster_silhouette_values.sort()

    size_cluster_i = ith_cluster_silhouette_values.shape[0]
    y_upper = y_lower + size_cluster_i

    color = cm.nipy_spectral(float(i) / n_cluster)
    ax1.fill_betweenx(
        np.arange(y_lower, y_upper),
        0,
        ith_cluster_silhouette_values,
        facecolor=color,
        edgecolor=color,
        alpha=0.7,
    )

    # Label the silhouette plots with their cluster numbers at the middle
    ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

    # Compute the new y_lower for next plot
    y_lower = y_upper + 10  # 10 for the 0 samples

ax1.set_title("The silhouette plot for the various clusters.")
ax1.set_xlabel("The silhouette coefficient values")
ax1.set_ylabel("Cluster label")

# The vertical line for average silhouette score of all the values
ax1.axvline(x=silhouettes_avg, color="red", linestyle="--")

ax1.set_yticks([])  # Clear the yaxis labels / ticks
ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

# 2nd Plot showing the actual clusters formed
colors = cm.nipy_spectral(cluster_labels.astype(float) / n_cluster)
ax2.scatter(
    cluster.iloc[:, 0], cluster.iloc[:, 1], marker=".", s=30, lw=0, alpha=0.7, c=colors, edgecolor="k"
)

# Labeling the clusters
centers = k_means.cluster_centers_
# Draw white circles at cluster centers
ax2.scatter(
    centers[:, 0],
    centers[:, 1],
    marker="o",
    c="white",
    alpha=1,
    s=200,
    edgecolor="k",
)

for i, c in enumerate(centers):
    ax2.scatter(c[0], c[1], marker="$%d$" % i, alpha=1, s=50, edgecolor="k")

ax2.set_title("The visualization of the clustered data.")
ax2.set_xlabel("Feature space for the 1st feature")
ax2.set_ylabel("Feature space for the 2nd feature")

plt.suptitle(
    "Silhouette analysis for KMeans clustering on sample data with n_clusters = %d"
    % n_cluster,
    fontsize=14,
    fontweight="bold",
)

plt.show()

# %% [markdown]
# # **Customer  + Log**

# %%
log_df=Log_Data02.copy()
log_df.head()
# Out:
#        거래일자  수수료율          고객ID  프로그램수정횟수  추가결제금액  거래취소여부  거래취소일자
# 0  20210201   6.5    5030100140       0.0    9800     NaN     NaN  \
# 1  20210201   6.5    8020105385       0.0       0     NaN     NaN
# 2  20210201   6.5  110104033157       0.0    9200     NaN     NaN
# 3  20210201   7.5   40203001176       0.0   11000     NaN     NaN
# 4  20210201   6.5    5041700297       0.0       0     NaN     NaN
#
#                               서비스명    판매자     판매금액    서비스가격   평점   이용자수  대분류
# 0    카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수  logf1  14800.0   5000.0  5.0  584.0  커머스  \
# 1    카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수  logf1   5000.0   5000.0  5.0  584.0  커머스
# 2  엑셀 VBA, 매크로, ERP 프로그램 개발해 드립니다.   엑셀의신  19200.0  10000.0  5.0  583.0  데이터
# 3    엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍    태구리  61000.0  50000.0  5.0  504.0  데이터
# 4    엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍    태구리  50000.0  50000.0  5.0  504.0  데이터
#
#     서비스번호
# 0  2102.0
# 1  2102.0
# 2  2103.0
# 3  2105.0
# 4  2105.0

# %%
log_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344299 entries, 0 to 344298
# Data columns (total 15 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   거래일자      344299 non-null  int64
#  1   수수료율      344299 non-null  float64
#  2   고객ID      344299 non-null  int64
#  3   프로그램수정횟수  344299 non-null  float64
#  4   추가결제금액    344299 non-null  int64
#  5   거래취소여부    4597 non-null    float64
#  6   거래취소일자    4597 non-null    float64
#  7   서비스명      344277 non-null  object
#  8   판매자       344277 non-null  object
#  9   판매금액      344278 non-null  float64
#  10  서비스가격     344277 non-null  float64
#  11  평점        344277 non-null  float64
#  12  이용자수      344277 non-null  float64
#  13  대분류       344277 non-null  object
#  14  서비스번호     344277 non-null  float64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 39.4+ MB

# %%
log_df.shape
# Out:
# (344299, 15)

# %%
log_df.isna().sum()
# Out:
# 거래일자             0
# 수수료율             0
# 고객ID             0
# 프로그램수정횟수         0
# 추가결제금액           0
# 거래취소여부      339702
# 거래취소일자      339702
# 서비스명            22
# 판매자             22
# 판매금액            21
# 서비스가격           22
# 평점              22
# 이용자수            22
# 대분류             22
# 서비스번호           22
# dtype: int64

# %%
log_df.drop(['거래취소여부','거래취소일자'],axis=1,inplace=True)

# %%
log_df[['거래일자']]
# Out:
#             거래일자
# 0       20210201
# 1       20210201
# 2       20210201
# 3       20210201
# 4       20210201
# ...          ...
# 344294  20210630
# 344295  20210630
# 344296  20210630
# 344297  20210630
# 344298  20210630
#
# [344299 rows x 1 columns]

# %%
log_df['거래일자']=log_df['거래일자'].astype('str')

# %%
log_df['연도']=log_df['거래일자'].apply(lambda x:x[:4])
log_df['월']=log_df['거래일자'].apply(lambda x:x[4:6])
log_df['일']=log_df['거래일자'].apply(lambda x:x[6:])

# %%
log_df['new_date']=log_df['연도']+'-'+log_df['월']+'-'+log_df['일']
log_df['new_date']=pd.to_datetime(log_df['new_date'])

# %%
log_df.head()
# Out:
#        거래일자  수수료율          고객ID  프로그램수정횟수  추가결제금액
# 0  20210201   6.5    5030100140       0.0    9800  \
# 1  20210201   6.5    8020105385       0.0       0
# 2  20210201   6.5  110104033157       0.0    9200
# 3  20210201   7.5   40203001176       0.0   11000
# 4  20210201   6.5    5041700297       0.0       0
#
#                               서비스명    판매자     판매금액    서비스가격   평점   이용자수  대분류
# 0    카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수  logf1  14800.0   5000.0  5.0  584.0  커머스  \
# 1    카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수  logf1   5000.0   5000.0  5.0  584.0  커머스
# 2  엑셀 VBA, 매크로, ERP 프로그램 개발해 드립니다.   엑셀의신  19200.0  10000.0  5.0  583.0  데이터
# 3    엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍    태구리  61000.0  50000.0  5.0  504.0  데이터
# 4    엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍    태구리  50000.0  50000.0  5.0  504.0  데이터
#
#     서비스번호    연도   월   일   new_date
# 0  2102.0  2021  02  01 2021-02-01
# 1  2102.0  2021  02  01 2021-02-01
# 2  2103.0  2021  02  01 2021-02-01
# 3  2105.0  2021  02  01 2021-02-01
# ...

# %%
log_df.drop(['거래일자'],axis=1,inplace=True)

# %%
log_df.describe()
# Out:
#                 수수료율          고객ID       프로그램수정횟수        추가결제금액          판매금액
# count  344299.000000  3.442990e+05  344299.000000  3.442990e+05  3.442780e+05  \
# mean        6.950001  3.870641e+10       0.173583  3.998393e+03  6.299230e+04
# min         6.500000  1.010102e+08      -1.000000  0.000000e+00  0.000000e+00
# 25%         6.500000  6.030206e+09       0.000000  0.000000e+00  1.000000e+04
# 50%         6.500000  1.307050e+10       0.000000  0.000000e+00  2.395000e+04
# 75%         7.500000  6.040301e+10       0.000000  6.500000e+03  5.000000e+04
# max         9.000000  1.501042e+11     119.000000  1.445200e+06  4.400000e+07
# std         0.788989  3.659226e+10       0.722254  9.074907e+03  2.568308e+05
#
#               서비스가격             평점           이용자수          서비스번호
# count  3.442770e+05  344277.000000  344277.000000  344277.000000  \
# mean   6.038945e+04       4.832186      54.798706    3034.824002
# min    5.000000e+03       0.000000       0.000000    2102.000000
# ...

# %%
category_col=log_df.select_dtypes('object').columns
number_col=log_df.select_dtypes(['int64','float64']).columns

# %%
log_df.head()
# Out:
#    수수료율          고객ID  프로그램수정횟수  추가결제금액                             서비스명
# 0   6.5    5030100140       0.0    9800    카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수  \
# 1   6.5    8020105385       0.0       0    카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수
# 2   6.5  110104033157       0.0    9200  엑셀 VBA, 매크로, ERP 프로그램 개발해 드립니다.
# 3   7.5   40203001176       0.0   11000    엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍
# 4   6.5    5041700297       0.0       0    엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍
#
#      판매자     판매금액    서비스가격   평점   이용자수  대분류   서비스번호    연도   월   일   new_date
# 0  logf1  14800.0   5000.0  5.0  584.0  커머스  2102.0  2021  02  01 2021-02-01
# 1  logf1   5000.0   5000.0  5.0  584.0  커머스  2102.0  2021  02  01 2021-02-01
# 2   엑셀의신  19200.0  10000.0  5.0  583.0  데이터  2103.0  2021  02  01 2021-02-01
# 3    태구리  61000.0  50000.0  5.0  504.0  데이터  2105.0  2021  02  01 2021-02-01
# 4    태구리  50000.0  50000.0  5.0  504.0  데이터  2105.0  2021  02  01 2021-02-01

# %%
# 연속형 변수 그래프

plt.figure(figsize=(20, 25))


for i, feature in enumerate(number_col, 1):
    plt.subplot(5, 3, i)
    sns.histplot(log_df[feature], bins=30, kde=True, color='skyblue', edgecolor='black')
    plt.title("Histogram: " + feature)
    plt.xlabel(feature)

plt.tight_layout()

# %%
plt.figure(figsize=(20, 25))


for i, feature in enumerate(number_col, 1):
    plt.subplot(5, 3, i)
    sns.boxplot(data=log_df, x=feature)
    plt.title("Boxplot: " + feature)
    plt.xlabel(feature)

plt.tight_layout()

# %%
# 범주형 변수 그래프

plt.figure(figsize=(20, 25))


for i, feature in enumerate(category_col, 1):
    plt.subplot(5, 3, i)
    sns.histplot(log_df[feature], bins=30, color='skyblue', edgecolor='black')
    plt.title("Histogram: " + feature)
    plt.xlabel(feature)

plt.tight_layout()

# %%
import koreanize_matplotlib

# %%
import matplotlib.font_manager as fm

# 한글 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'  # 폰트 파일의 경로
fontprop = fm.FontProperties(fname=font_path)
plt.rc('font', family=fontprop.get_name())

# %%
monthly_sales = log_df.groupby(['연도', '월'])['판매금액'].sum().reset_index()
monthly_users = log_df.groupby(['연도', '월'])['이용자수'].sum().reset_index()

# 시계열 그래프 생성
plt.figure(figsize=(14, 7))

plt.subplot(2, 1, 1)
plt.plot(monthly_sales['월'], monthly_sales['판매금액'], marker='o', linestyle='-')
plt.title('월별 판매금액 트렌드')
plt.xlabel('월')
plt.ylabel('판매금액')

plt.subplot(2, 1, 2)
plt.plot(monthly_users['월'], monthly_users['이용자수'], marker='o', linestyle='-')
plt.title('월별 이용자수 트렌드')
plt.xlabel('월')
plt.ylabel('이용자수')

plt.tight_layout()
plt.show()

# %%
# 카테고리별 총 판매금액

categories= log_df['대분류'].unique()

category_sales = log_df.groupby('대분류')['판매금액'].sum().reset_index()
category_sales.columns = ['대분류', '총판매금액']

# 카테고리별 평균 평점
category_rating = log_df.groupby('대분류')['평점'].mean().reset_index()
category_rating.columns = ['대분류', '평균평점']

# 카테고리별 총 이용자 수
category_users = log_df.groupby('대분류')['이용자수'].sum().reset_index()
category_users.columns = ['대분류', '총이용자수']

# 카테고리별 월별 판매금액 추이
monthly_category_sales = log_df.groupby(['연도', '월', '대분류'])['판매금액'].sum().reset_index()

# 데이터프레임 합치기
category_analysis = pd.merge(category_sales, category_rating, on='대분류')
category_analysis = pd.merge(category_analysis, category_users, on='대분류')

# 결과 표시
print("카테고리별 분석 결과")
print(category_analysis)

# 시각화
import matplotlib.pyplot as plt

# 카테고리별 총 판매금액 시각화
plt.figure(figsize=(12, 6))
plt.bar(category_sales['대분류'], category_sales['총판매금액'], color='skyblue')
plt.xlabel('대분류')
plt.ylabel('총판매금액')
plt.title('카테고리별 총 판매금액')
plt.show()

# 카테고리별 평균 평점 시각화
plt.figure(figsize=(12, 6))
plt.bar(category_rating['대분류'], category_rating['평균평점'], color='lightgreen')
plt.xlabel('대분류')
plt.ylabel('평균평점')
plt.title('카테고리별 평균 평점')
plt.show()

# 카테고리별 총 이용자수 시각화
plt.figure(figsize=(12, 6))
plt.bar(category_users['대분류'], category_users['총이용자수'], color='lightcoral')
plt.xlabel('대분류')
plt.ylabel('총이용자수')
plt.title('카테고리별 총 이용자수')
plt.show()

# 카테고리별 월별 판매금액 추이 시각화
plt.figure(figsize=(14, 8))
for category in categories:
    monthly_data = monthly_category_sales[monthly_category_sales['대분류'] == category]
    plt.plot(monthly_data['월'], monthly_data['판매금액'], marker='o', linestyle='-', label=category)

plt.xlabel('월')
plt.ylabel('판매금액')
plt.title('카테고리별 월별 판매금액 추이')
plt.legend()
plt.show()
# Out:
# 카테고리별 분석 결과
#        대분류         총판매금액      평균평점      총이용자수
# 0   UnReal  2.750348e+08  4.116410    14327.0
# 1       게임  2.117983e+08  4.619233   204224.0
# 2       기타  2.092080e+09  4.864449  2187002.0
# 3       기획  4.305127e+08  4.667481   113063.0
# 4      데이터  2.306413e+09  4.757946  4392481.0
# 5      디자인  3.267316e+08  4.225100   150736.0
# 6      모바일  2.895643e+09  4.810406   331362.0
# 7     인공지능  1.273871e+08  4.922025    17922.0
# 8      커머스  9.153912e+08  4.918999  2511550.0
# 9    프로그래밍  2.741544e+09  4.864311  1263975.0
# 10    프로그램  2.004982e+09  4.797541  1036353.0
# 11    홈페이지  7.359346e+09  4.874239  6642939.0

# %% [markdown]
# 1. IT 아웃소싱 시장에서 외주를 의뢰하는 소비자의 서비스 니즈 파악을 통해 의뢰 고객들에게 차별화 서비스를 제공하고자 한다.
# 2. 아웃소싱 전문가들과 구매 소비자들의 거래 성사율을 높이기 위한 차별화된 서비스 홍보를 하고자 한다.
# 3. 적절한 거래 수수료를 책정하여 소비자와 전문가의 거래가 지속적으로 이어질 수 있는 방안을 도출하고자 한다.

# %%
log_df.head()
# Out:
#    수수료율          고객ID  프로그램수정횟수  추가결제금액                             서비스명
# 0   6.5    5030100140       0.0    9800    카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수  \
# 1   6.5    8020105385       0.0       0    카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수
# 2   6.5  110104033157       0.0    9200  엑셀 VBA, 매크로, ERP 프로그램 개발해 드립니다.
# 3   7.5   40203001176       0.0   11000    엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍
# 4   6.5    5041700297       0.0       0    엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍
#
#      판매자     판매금액    서비스가격   평점   이용자수  대분류   서비스번호    연도   월   일   new_date
# 0  logf1  14800.0   5000.0  5.0  584.0  커머스  2102.0  2021  02  01 2021-02-01
# 1  logf1   5000.0   5000.0  5.0  584.0  커머스  2102.0  2021  02  01 2021-02-01
# 2   엑셀의신  19200.0  10000.0  5.0  583.0  데이터  2103.0  2021  02  01 2021-02-01
# 3    태구리  61000.0  50000.0  5.0  504.0  데이터  2105.0  2021  02  01 2021-02-01
# 4    태구리  50000.0  50000.0  5.0  504.0  데이터  2105.0  2021  02  01 2021-02-01

# %%
log_df.describe()
# Out:
#                 수수료율          고객ID       프로그램수정횟수        추가결제금액          판매금액
# count  344299.000000  3.442990e+05  344299.000000  3.442990e+05  3.442780e+05  \
# mean        6.950001  3.870641e+10       0.173583  3.998393e+03  6.299230e+04
# min         6.500000  1.010102e+08      -1.000000  0.000000e+00  0.000000e+00
# 25%         6.500000  6.030206e+09       0.000000  0.000000e+00  1.000000e+04
# 50%         6.500000  1.307050e+10       0.000000  0.000000e+00  2.395000e+04
# 75%         7.500000  6.040301e+10       0.000000  6.500000e+03  5.000000e+04
# max         9.000000  1.501042e+11     119.000000  1.445200e+06  4.400000e+07
# std         0.788989  3.659226e+10       0.722254  9.074907e+03  2.568308e+05
#
#               서비스가격             평점           이용자수          서비스번호
# count  3.442770e+05  344277.000000  344277.000000  344277.000000  \
# mean   6.038945e+04       4.832186      54.798706    3034.824002
# min    5.000000e+03       0.000000       0.000000    2102.000000
# ...

# %% [markdown]
# ## 파생변수 생성

# %%
log_df['총금액'] = log_df['판매금액'] + log_df['추가결제금액']

# %%
log_df
# Out:
#         수수료율          고객ID  프로그램수정횟수  추가결제금액                             서비스명  \
# 0        6.5    5030100140       0.0    9800    카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수
# 1        6.5    8020105385       0.0       0    카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수
# 2        6.5  110104033157       0.0    9200  엑셀 VBA, 매크로, ERP 프로그램 개발해 드립니다.
# 3        7.5   40203001176       0.0   11000    엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍
# 4        6.5    5041700297       0.0       0    엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍
# ...      ...           ...       ...     ...                              ...
# 344294   9.0   50150001196       0.0       0           데이터 분석 및 시각화 제공해 드립니다.
# 344295   7.5   60107010137       0.0       0           데이터 분석 및 시각화 제공해 드립니다.
# 344296   9.0   70406002101       0.0       0           데이터 분석 및 시각화 제공해 드립니다.
# 344297   6.5    9010306354       0.0       0           데이터 분석 및 시각화 제공해 드립니다.
# 344298   7.5    9030200780       0.0   10000           데이터 분석 및 시각화 제공해 드립니다.
#
# ...

# %%
log_df[['서비스명']].value_counts().head(15)
# Out:
# 서비스명
# VBA 프로그램 , 엑셀 매크로 제작해 드립니다.             3738
# 리눅스 기술지원, 장애처리, 서버이전, 서버구축              3727
# 카페24,고도몰,메이크샵,모든쇼핑몰 수정,오류,문제해결          2851
# 생산,재고,급여,데이터 엑셀화로 업무의 효율을 높여 드립니다.      2729
# 고퀄리티의 퍼블리싱을 구현해 드립니다.                   2482
# 쇼핑몰에 카페24등 SNS 로그인 6종 연동해 드립니다          2344
# 홈페이지 수정, 이미지 및 텍스트 등 간단 수정              2273
# 카페24 쇼핑몰 기능제작 및 간단한 수정해 드립니다.           2270
# 뜯어보면서 공부할 수 있는 게임 기능을 만들어드립니다.          1983
# 퍼블리싱 HTML, CSS, JS, jQuery 코딩해 드립니다.    1946
# VBA 막힐 때 물어보세요                          1918
# 엑셀 문서 작성해드립니다. VBA,매크로,파워쿼리             1904
# 모든 SQL 쿼리 개발 및 전환 을 도와 드립니다.            1890
# 포털 사이트 키워드 검색량 일별로 추출 및 분석해 드립니다.       1810
# 쇼핑몰배너 상세페이지 온라인배너 제작해 드립니다.             1767
# Name: count, dtype: int64

# %%
log_df[['서비스명']].nunique()
# Out:
# 서비스명    2787
# dtype: int64

# %%
log_df['서비스명']
# Out:
# 0           카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수
# 1           카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수
# 2         엑셀 VBA, 매크로, ERP 프로그램 개발해 드립니다.
# 3           엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍
# 4           엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍
#                        ...
# 344294             데이터 분석 및 시각화 제공해 드립니다.
# 344295             데이터 분석 및 시각화 제공해 드립니다.
# 344296             데이터 분석 및 시각화 제공해 드립니다.
# 344297             데이터 분석 및 시각화 제공해 드립니다.
# 344298             데이터 분석 및 시각화 제공해 드립니다.
# Name: 서비스명, Length: 344299, dtype: object

# %%
service_count=log_df['서비스명'].value_counts().reset_index()
service_count.columns=['서비스명','count']
service_count
# Out:
#                                     서비스명  count
# 0            VBA 프로그램 , 엑셀 매크로 제작해 드립니다.   3738
# 1             리눅스 기술지원, 장애처리, 서버이전, 서버구축   3727
# 2         카페24,고도몰,메이크샵,모든쇼핑몰 수정,오류,문제해결   2851
# 3     생산,재고,급여,데이터 엑셀화로 업무의 효율을 높여 드립니다.   2729
# 4                  고퀄리티의 퍼블리싱을 구현해 드립니다.   2482
# ...                                  ...    ...
# 2782                카페24 쇼핑몰 디자인 작업해드립니다      1
# 2783             ML/AI Modeling 진행해드립니다.      1
# 2784                  언리얼 상업 게임 개발해드립니다.      1
# 2785      반응형 랜딩페이지부터 원페이지까지 퍼블리싱해 드립니다.      1
# 2786                   디스코드 봇 주문제작 드립니다.      1
#
# [2787 rows x 2 columns]

# %%
keywords = log_df['서비스명'].str.split(expand=True).stack().value_counts().reset_index()
keywords.columns = ['키워드', '빈도']
keywords
# Out:
#         키워드      빈도
# 0     드립니다.  245079
# 1         및   56826
# 2       제작해   43455
# 3         해   40443
# 4      홈페이지   31828
# ...     ...     ...
# 4063     터칭       1
# 4064     마틴       1
# 4065   해주시면       1
# 4066    설명만       1
# 4067  클라이언트       1
#
# [4068 rows x 2 columns]

# %%
! pip install konlpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 73.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 27.3 MB/s eta 0:00:00
# ...

# %%
from konlpy.tag import Okt

# Okt를 이용한 명사 추출
okt = Okt()

nouns = []
for service in log_df['서비스명']:
    if isinstance(service, str):
        nouns.extend(okt.nouns(service))

# 명사 빈도 계산
noun_counts = Counter(nouns)

# 상위 10개 명사 출력
for noun, count in noun_counts.most_common(10):
    print(noun, count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-60a3e90c9dc6> in <cell line: 12>()
#      10
#      11 # 명사 빈도 계산
# ---> 12 noun_counts = Counter(nouns)
#      13
#      14 # 상위 10개 명사 출력
#
# NameError: name 'Counter' is not defined

# %%
nouns_df = pd.Series(nouns).value_counts().reset_index()
nouns_df.columns = ['명사', '빈도']

# %%
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(dict(zip(nouns_df['명사'], nouns_df['빈도'])))
plt.figure(figsize=(14, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('서비스명 주요 명사 클라우드', fontsize=20)
plt.show()

# %%
# prompt: 키워드 하나씩 삭제할 수 있는 코드

def remove_keyword(keywords, keyword_to_remove):
  """
  주어진 키워드를 삭제하고 업데이트된 키워드 리스트를 반환합니다.

  Args:
    keywords: 키워드와 빈도를 포함하는 pandas DataFrame.
    keyword_to_remove: 삭제할 키워드.

  Returns:
    업데이트된 키워드 리스트를 포함하는 pandas DataFrame.
  """
  updated_keywords = keywords[keywords['키워드'] != keyword_to_remove]
  return updated_keywords

# 예시 사용:
keyword_to_remove = "드립니다."  # 삭제할 키워드
updated_keywords = remove_keyword(keywords, keyword_to_remove)

print("업데이트된 키워드:")
print(updated_keywords)
# Out:
# 업데이트된 키워드:
#         키워드     빈도
# 1         및  56826
# 2       제작해  43455
# 3         해  40443
# 4      홈페이지  31828
# 5         웹  30380
# ...     ...    ...
# 4063     터칭      1
# 4064     마틴      1
# 4065   해주시면      1
# 4066    설명만      1
# 4067  클라이언트      1
#
# [4067 rows x 2 columns]

# %%
keyword_to_remove = "및"  # 삭제할 키워드
updated_keywords = remove_keyword(keywords, keyword_to_remove)

# %%
keyword_to_remove = "제작해"  # 삭제할 키워드
updated_keywords = remove_keyword(keywords, keyword_to_remove)

# %%
keyword_to_remove ='해'  # 삭제할 키워드
updated_keywords = remove_keyword(keywords, keyword_to_remove)

# %%
updated_keywords['키워드'].unique()
# Out:
# array(['드립니다.', '및', '제작해', ..., '해주시면', '설명만', '클라이언트'], dtype=object)

# %%
merge_df=pd.merge(customer,Log_Data02,on='고객ID',how='right')

# %%
merge_df.head()
# Out:
#            고객ID      사용기기          사용OS    유입경로  회원상태  거주지    연령   성별  \
# 0    5030100140    iPhone     iOS11.4.1     유튜브  정상회원  경상도  20.0   남성
# 1    8020105385  SM-N950N  Android7.1.1   인스타그램  정상회원  경기도  27.0   남성
# 2  110104033157    iPhone     iOS11.4.1     유튜브  정상회원  경기도  29.0   남성
# 3   40203001176    iPhone     iOS11.0.3     유튜브  정상회원  전라도  20.0  NaN
# 4    5041700297    iPhone     iOS11.4.1  네이버블로그  정상회원  제주도  32.0   남성
#
#    서비스총구매수     총구매금액  ...  거래취소여부  거래취소일자                             서비스명  \
# 0        8  250400.0  ...     NaN     NaN    카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수
# 1        3   60000.0  ...     NaN     NaN    카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수
# 2        1   19200.0  ...     NaN     NaN  엑셀 VBA, 매크로, ERP 프로그램 개발해 드립니다.
# 3        5  645000.0  ...     NaN     NaN    엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍
# 4        6  203000.0  ...     NaN     NaN    엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍
#
#      판매자     판매금액    서비스가격   평점   이용자수  대분류   서비스번호
# ...

# %%
expert_Data.head()
# Out:
#   판매자ID         판매자  판매 서비스 수    총 판매 금액 프리미엄 서비스 가입여부 신속 알람 서비스 사용여부
# 0  V2_0         김러그       326  147927420            가입            미사용
# 1  V2_1        디프라이        43  146832200            가입            미사용
# 2  V2_2    Sailorkr        14  140029000            가입            미사용
# 3  V2_3  신뢰할만한지식인65        16  130713200            가입            미사용
# 4  V2_4         에픽핫        18  126229400            가입            미사용

# %%
Service_Data.head()
# Out:
#                             서비스명         판매자      서비스가격   평점    대분류   서비스번호
# 0   "P2P 대출" 서비스를 위한 기획을 해 드립니다.     디자인쇼크리더   400000.0  0.0     기획  5651.0  \
# 1  "반응형 웹 퍼블리싱" 모든 퍼블리싱 작업 맞춤 진행  ThunDesign    15000.0  0.0   홈페이지  6122.0
# 2     "이커머스 웹 사이트개발 경력자"의 쇼핑몰 제작      IAMTRY   500000.0  0.0    커머스  6152.0
# 3    .NET C# 개발. WPF 또는 WinForms          혼살  1200000.0  5.0  프로그래밍  5009.0
# 4     .NET, c# 응용프로그램 개발, delphi  JAVASCRIPT    60000.0  5.0   프로그램  4419.0
#
#    판매수
# 0    6
# 1    1
# 2    3
# 3    1
# 4   10
